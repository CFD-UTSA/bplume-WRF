# %%
import sys
sys.path.insert(1, r'C:\Users\thanh\OneDrive - University of Texas at San Antonio\Pyplume')
import pyplume as pl

import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# %%
T = np.load(r"D:\new_nbl_test_case\a.wrfoutnpy\U_dt60.npy")
# T = T+300
# Q = np.load(r"D:\cbl.co.u.2ms.h.2.5\a.wrfoutnpy\T_dt60.npy")

# %%
nt,nz,ny,nx = np.shape(T)
print(np.shape(T))
# Out:
# (10, 200, 100, 200)

# %%
for i in range (0,200,20):
    temp = np.mean(T,0)
    temp = temp[:,50,i]
    plt.title(str(i))
    plt.plot(temp)
    plt.show()

# %%
for t in range(0,nt,1):
    plt.contourf(T[t,:,50,:])
    plt.title(str(t+1)+" minutes")
    plt.colorbar()
    plt.show()

# %%
for t in range(0,nt,1):
    plt.contourf(Q[t,:,:,1])
    plt.title(str(t+1)+" minutes")
    plt.colorbar()
    plt.show()

# %%
T = np.load(r"D:\cbl.co.u.2ms.h.2.5\a.wrfoutnpy\QPLUME_mean.npy")

# plt.contourf(np.mean(T,1))
plt.contourf(T[:,50,:],110,vmax = 0.001,vmin = 0.00000001)
# plt.title(str(t+1)+" minutes")
plt.colorbar()
plt.show()
