# %%
import sys
sys.path.insert(1, r'C:\Users\thanh\OneDrive - University of Texas at San Antonio\Pyplume')
import pyplume as pl

import numpy as np
from numpy import linalg as LA
import matplotlib.pyplot as plt
from datetime import datetime

# %%
T = np.load(r"D:\J_new\adiabatic\T.npy")
# T_constant = np.load(r"D:\J_new\constantprofile\T.npy")

# %%
Tmean = np.mean(np.mean(T,0),0)

# %%
print(np.shape(T))
# Out:
# (100, 100, 200, 360)

# %%
for t in range(0,360,10):
    f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(15,7))
    ax1.contourf(T[:,50,:100,t].T)
    ax2.scatter(Tmean[:100,t],np.arange(100))
    f.suptitle(str(t*10)+" s")
    plt.show()
